# %%
# This notebook will return all the deep time vocabulary scheme names in the iscallnew graph in a triple store

install.packages("SPARQL")
library(SPARQL)
# Out:
# Installing package into ‘/nethome/max/.R-libs’
# (as ‘lib’ is unspecified)

# %%
# set up end point and prefix
endpoint = "http://virtuoso.nkn.uidaho.edu:8890/sparql/"
  
# attach SPARQL querry prefix. Note: the graph for our study should be updated
sparql_prefix = " 
                prefix dc: <http://purl.org/dc/elements/1.1/>
                prefix gts: <http://resource.geosciml.org/ontology/timescale/gts#>
                prefix skos: <http://www.w3.org/2004/02/skos/core#>
                prefix time: <http://www.w3.org/2006/time#>
                prefix ts: <http://resource.geosciml.org/vocabulary/timescale/> 
                prefix isc: <http://resource.geosciml.org/classifier/ics/ischart/> 
        "

# %%
# the query code
 
q = paste0(
              sparql_prefix, 
                  '
                   SELECT   DISTINCT  ?schURI  str(?lbl) AS ?schemeName
                   WHERE
                   {
                     GRAPH <http://deeptimekb.org/iscallnew> 
                     {
                        ?schURI a skos:ConceptScheme ;
                             rdfs:label ?lbl .
                     }      
                   }
                  '
              )

# %%
# run the query  
res = SPARQL(endpoint, q)$results
  
return(res)
# Out:
#    schURI
# 1  <http://resource.geosciml.org/vocabulary/timescale/tsnc2019>
# 2  <http://resource.geosciml.org/vocabulary/timescale/tssc2019>
# 3  <http://resource.geosciml.org/vocabulary/timescale/tsnz2019>
# 4  <http://resource.geosciml.org/vocabulary/timescale/tsau2019>
# 5  <http://resource.geosciml.org/vocabulary/timescale/tsba2019>
# 6  <http://resource.geosciml.org/vocabulary/timescale/tsbr2019>
# 7  <http://resource.geosciml.org/vocabulary/timescale/tsjp2019>
# 8  <http://resource.geosciml.org/vocabulary/timescale/tswe2019>
# 9  <http://resource.geosciml.org/vocabulary/timescale/tsna2019>
# 10 <http://resource.geosciml.org/vocabulary/timescale/isc2004-04>
# 11 <http://resource.geosciml.org/vocabulary/timescale/isc2005-12>
# 12 <http://resource.geosciml.org/vocabulary/timescale/isc2006-04>
# 13 <http://resource.geosciml.org/vocabulary/timescale/isc2008-08>
# 14 <http://resource.geosciml.org/vocabulary/timescale/isc2009-08>
# 15 <http://resource.geosciml.org/vocabulary/timescale/isc2010-09>
# 16 <http://resource.geosciml.org/vocabulary/timescale/isc2012-08>
# 17 <http://resource.geosciml.org/vocabulary/timescale/isc2013-01>
# 18 <http://resource.geosciml.org/vocabulary/timescale/isc2014-02>
# 19 <http://resource.geosciml.org/vocabulary/timescale/isc2014-10>
# 20 <http://resource.geosciml.org/vocabulary/timescale/isc2015-01>
# 21 <http://resource.geosciml.org/vocabulary/timescale/isc2016-04>
# 22 <http://resource.geosciml.org/vocabulary/timescale/isc2016-10>
# 23 <http://resource.geosciml.org/vocabulary/timescale/isc2017-02>
# 24 <http://resource.geosciml.org/vocabulary/timescale/isc2018-07>
# 25 <http://resource.geosciml.org/vocabulary/timescale/isc2018-08>
#    schemeName
# 1  Ontology for Geologic Timescale Elements in North China
# 2  Ontology for Geologic Timescale Elements in South China
# 3  Ontology for Geologic Timescale Elements in New Zealand
# 4  Ontology for Geologic Timescale Elements in Australia
# 5  Ontology for Geologic Timescale Elements in Baltoscania
# 6  Ontology for Geologic Timescale Elements in Britain
# 7  Ontology for Geologic Timescale Elements in Japan
# 8  Ontology for Geologic Timescale Elements in West Europe
# 9  Ontology for Geologic Timescale Elements in North America
# 10 International Chronostratigraphic Chart (2004)
# 11 International Chronostratigraphic Chart (2005)
# 12 International Chronostratigraphic Chart (2006)
# 13 International Chronostratigraphic Chart (2008)
# 14 International Chronostratigraphic Chart (2009)
# 15 International Chronostratigraphic Chart (2010)
# 16 International Chronostratigraphic Chart (2012)
# 17 International Chronostratigraphic Chart (2013)
# 18 International Chronostratigraphic Chart (2014)
# 19 International Chronostratigraphic Chart (2014)
# 20 International Chronostratigraphic Chart (2015)
# 21 International Chronostratigraphic Chart (2016)
# 22 International Chronostratigraphic Chart (2016)
# 23 International Chronostratigraphic Chart (2017)
# 24 International Chronostratigraphic Chart (2018)
# 25 International Chronostratigraphic Chart (2018)
