# %%
import sparql
from tabulate import tabulate

# %%
# set up end point and prefix
endpoint = "http://virtuoso.nkn.uidaho.edu:8890/sparql/"

# attach SPARQL querry prefix. Note: the graph for our study should be updated
sparql_prefix = """ 
prefix dc: <http://purl.org/dc/elements/1.1/> 
prefix dcterms: <http://purl.org/dc/terms/> 
prefix foaf: <http://xmlns.com/foaf/0.1/> 
prefix geo: <http://www.opengis.net/ont/geosparql#> 
prefix gts: <http://resource.geosciml.org/ontology/timescale/gts#> 
prefix isc: <http://resource.geosciml.org/classifier/ics/ischart/> 
prefix owl: <http://www.w3.org/2002/07/owl#> 
prefix rank: <http://resource.geosciml.org/ontology/timescale/rank/> 
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
prefix samfl: <http://def.seegrid.csiro.au/ontology/om/sam-lite#> 
prefix sf: <http://www.opengis.net/ont/sf#> 
prefix skos: <http://www.w3.org/2004/02/skos/core#> 
prefix sosa: <http://www.w3.org/ns/sosa/> 
prefix thors: <http://resource.geosciml.org/ontology/timescale/thors#> 
prefix time: <http://www.w3.org/2006/time#> 
prefix ts: <http://resource.geosciml.org/vocabulary/timescale/> 
prefix vann: <http://purl.org/vocab/vann/> 
prefix void: <http://rdfs.org/ns/void#> 
prefix xkos: <http://rdf-vocabulary.ddialliance.org/xkos#> 
prefix xsd: <http://www.w3.org/2001/XMLSchema#> 
prefix tsna: <http://deeptimekb.org/tsna#> 
prefix tssc: <http://deeptimekb.org/tssc#> 
prefix tsnc: <http://deeptimekb.org/tsnc#> 
prefix tsnz: <http://deeptimekb.org/tsnz#> 
prefix tswe: <http://deeptimekb.org/tswe#> 
prefix tsbr: <http://deeptimekb.org/tsbr#> 
prefix tsba: <http://deeptimekb.org/tsba#> 
prefix tsjp: <http://deeptimekb.org/tsjp#> 
prefix tsau: <http://deeptimekb.org/tsau#> 
        """

# %%
sparql_prefix += """
SELECT DISTINCT ?sch str(?lbl) ?baseNum
WHERE
{
                
   GRAPH <http://deeptimekb.org/iscallnew>
   { 
      {
        # ?sch  a skos:ConceptScheme ;
              rdfs:label ?slabel . 
        FILTER(regex(STR(?slabel), "North America", "i"))
      }

    UNION 
      {
        # ?sch  a skos:ConceptScheme . 
        FILTER(regex(STR(?sch),"tsna", "i"))
      }

     # ?concept  a gts:GeochronologicEra ,
                 gts:Age ; 
               rdfs:label ?lbl ;
               skos:inScheme ?sch ;
               time:hasBeginning ?basePosition .  
     # ?basePosition time:inTemporalPosition ?baseTime .
     # ?baseTime time:numericPosition ?baseNum .
    }
   
}
ORDER BY ?baseNum
                  """

result = sparql.query(endpoint, sparql_prefix)
rows = [sparql.unpack_row(row) for row in result]
print(tabulate(rows, result.variables))
# Out:
# sch                                                         callret-1            baseNum
# ----------------------------------------------------------  -----------------  ---------
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Capitanian Age        265.14
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Wordian Age           268.8
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Roadian Age           272.3
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Cathedralian Age      278.12
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Hessian Age           284.02
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Lenoxian Age          295.5
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Nealian Age           298.88
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Virgilian Age         303.51
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Missourian Age        305.91
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Desmoinesian Age      312.67
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Atokan Age            318.65
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Morrowan Age          323.23
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Chesterian Age        334.92
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Meramecian Age        345.4
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Osagean Age           352.35
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Kinderhookian Age     358.94
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Chatauquan Age        368.38
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Senecan Age           384.8
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Erian Age             387.72
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Ulsterian Age         419.2
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Cayugan Age           425.57
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Niagaran Age          439.99
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Medinan Age           443.83
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Gamachian Age         445.32
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Richmondian Age       448.84
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Maysvillian Age       449.82
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Edenian Age           450.96
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Chatfieldian Age      453.89
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Turinian Age          456.72
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Rangerian Age         469.96
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Blackhillsian Age     475.1
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Tulean Age            479.6
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Stairsian Age         480.17
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Skullrockian Age      486.73
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Sunwaptan Age         492.97
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Steptoean Age         497
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Marjuman Age          504.5
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Topazan Age           506.8
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Delamaran Age         511.4
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Dyeran Age            515.2
# http://resource.geosciml.org/vocabulary/timescale/tsna2019  Montezuman Age        519.25
